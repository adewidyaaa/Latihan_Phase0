# %% [markdown]
# <a href="https://colab.research.google.com/github/adewidyaaa/Latihan_Phase0/blob/main/Salinan_dari_Kisi_Kisi_LC2_P0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # **Kisi-kisi LC2**
#
# Dataset yang digunakan pada latihan ini berasal dari bigquery public data. Lakukan koneksi Google Colaboratory dengan BigQuery menggunakan syntax berikut:
#
# ```
# from google.colab import auth
# from google.cloud import bigquery
# auth.authenticate_user()
# print('Authenticated')
#
# project_id = "hckv8-95102" #GUNAKAN GCP PROJECT-ID KALIAN MASING-MASING
# client = bigquery.Client(project=project_id)
# ```
#
# lalu lakukan query pada notebook menggunakan cara berikut:
#
# ```
# df_1 = client.query('''
# SELECT *
# FROM table_name`
# ''').to_dataframe()
#
# df_1
# ```
#
# ---
#
# Dataset yang digunakan merupakan `record perjalanan peminjam sepeda`, dapat diakses pada:
#
# - **Project_id_Database**: ftds-hacktiv8-project
# - **Dataset**            : practice
# - **Table**              : bike_rent
#
# Lakukan pengolahan SQL langsung melalui Google Colaboratory yang telah dikoneksikan pada BigQuery
#
# ---
# Pada notebook ini terdapat 2 section, **SQL** dan **Pandas**.
#
# Kerjakan masing-masing section sesuai dengan ketentuan di bawah:
#
# ## A. **SQL**
#
#   >**Jawab masing-masing soal dalam 1 query.**
#
#   1. Berapa banyak label unique dari `bike_type`?
#   2. Apa saja nama label unique dari tipe sepeda?
#   3. Berapa banyak total peminjaman sepeda pada tahun 2016 dan 2017?
#   4. Dimana station yang paling banyak dikunjungi sebagai titik keberangkatan pada tahun 2016?
#   5. Berapa nilai minimum, maximum, dan rata-rata dari durasi perjalanan pada keseluruhan data?
#   6. Berapa rata-rata durasi perjalanan dari subscriber_type `Explorer` dan `Weekender`?
#   7. Tampilkan entry data yang memiliki `duration_time` diatas 4.25 jam. (*Gunakan subquery untuk menjawab pertanyaan ini dengan meng-convert duration_time dari menit ke hour*).
#
# ## B. **Pandas**
#   >**Data yang akan diolah menggunakan Pandas wajib diambil menggunakan Query berikut:**
#   ```
#   SELECT *
#   FROM `ftds-hacktiv8-project.practice.bike_rent`
#   ```
#
#   >Simpan data yang telah diambil ke dalam variabel `df` (penamaan variabel dibebaskan), **lakukan pengolah di bawah ini menggunakan library Pandas**:
#
#   1. Cek kesesuaian tipe data dan keberadaan missing values dengan `.info()`
#
#   2. Buat kolom baru bernama `quarter`.
#
#   Lakukan ekstraksi waktu (quarter dalam tahun) berdasarkan kolom `start_time` dengan ketentuan berikut:
#
# <div align="center">
#
#   |Keterangan Waktu|Bulan|
#   |--|--|
#   |Q1|Januari, Februari, Maret|
#   |Q2|April, Mei, Juni|
#   |Q3|Juli, Agustus, September|
#   |Q4|Oktober, November, Desember|
#
# </div>
#
#   3. Tampilkan data perjalanan dari tipe member `Local365` dengan durasi perjalanan diatas 1 jam *`(Jika tidak ada entry yang memenuhi kondisi ini tidak apa, tuliskan kode pandasnya dengan lengkap saja)`*.
#
#   4. Berapa rata-rata durasi perjalanan dari tipe pelanggan `Walk Up` dengan tipe sepeda `classic` pada bulan `Maret` berdasarkan data yang diambil? *`(Jika tidak ada entry yang memenuhi kondisi ini tidak apa, tuliskan kode pandasnya dengan lengkap saja)`*.
#
# >**Notes:**
# >- Dalam menjawab soal Pandas no. 2, **tidak boleh** menggunakan ekstraksi waktu `Series.dt.quarter`
# - Lakukan `looping` dan `conditional` dengan memanfaatkan ekstraksi bulan `Series.dt.month` terhadap kolom `start_time`, pastikan tipe datanya ialah `datetime` agar dapat dilakukan ekstraksi.
# - Simpan hasil looping ke dalam suatu variabel, dan buat kolom baru berisikan variabel sebelumnya.

# %%
from google.colab import auth
from google.cloud import bigquery
auth.authenticate_user()
print('Authenticated')
# Out:
# Authenticated

# %%
project_id = "project-hacktiv8-ade" #GUNAKAN GCP PROJECT-ID KALIAN MASING-MASING
client = bigquery.Client(project=project_id)

# %%
df_1 = client.query('''
SELECT *
FROM ftds-hacktiv8-project.practice.bike_rent
''').to_dataframe()

df_1
# Out:
#        trip_id subscriber_type bike_id bike_type                start_time  \
# 0     18896589        Explorer      93   classic 2018-10-28 14:16:14+00:00
# 1     13948351        Local365     315   classic 2017-03-07 12:37:33+00:00
# 2     16243803        Local365     877   classic 2017-10-21 09:49:48+00:00
# 3     16222446         Walk Up     273   classic 2017-10-18 15:01:52+00:00
# 4     16222451         Walk Up     201   classic 2017-10-18 15:02:26+00:00
# ...        ...             ...     ...       ...                       ...
# 7995  15469480         Walk Up     327   classic 2017-07-22 20:17:46+00:00
# 7996  16130650         Walk Up     528   classic 2017-10-07 11:25:36+00:00
# 7997  14204138         Walk Up     235   classic 2017-03-27 13:19:02+00:00
# 7998  15037809         Walk Up     206   classic 2017-06-05 11:42:40+00:00
# 7999   9499076         Walk Up     315   classic 2016-04-09 18:52:09+00:00
#
#                            start_station_name  \
# 0                     Dean Keeton & Speedway
# 1                                 Main Office
# 2           Republic Square @ 5th & Guadalupe
# 3             Bullock Museum @ Congress & MLK
# 4             Bullock Museum @ Congress & MLK
# ...                                       ...
# 7995          Bullock Museum @ Congress & MLK
# 7996                  Congress & Cesar Chavez
# 7997          State Capitol @ 14th & Colorado
# 7998          State Capitol @ 14th & Colorado
# 7999  Capital Metro HQ - East 5th at Broadway
#
#                              end_station_name  duration_minutes
# 0                              11th & Salina                178
# 1                                 Main Office               198
# 2                                 Main Office                60
# 3                                 Main Office                60
# 4                                 Main Office                60
# ...                                       ...               ...
# 7995          Bullock Museum @ Congress & MLK                55
# 7996          Bullock Museum @ Congress & MLK                55
# 7997          State Capitol @ 14th & Colorado                55
# 7998          State Capitol @ 14th & Colorado                55
# 7999  Capital Metro HQ - East 5th at Broadway                55
#
# [8000 rows x 8 columns]

# %% [markdown]
# ###**SQL**

# %% [markdown]
# #####1. Berapa banyak label unique dari bike_type?

# %%
# working area

df_bike_type_unique = client.query('''
SELECT COUNT(DISTINCT bike_type)
FROM ftds-hacktiv8-project.practice.bike_rent
''').to_dataframe()

df_bike_type_unique
# Out:
#    f0_
# 0    2

# %% [markdown]
# #####2. Apa saja nama label unique dari tipe sepeda?

# %%
# working area

df_bike_type_unique2 = client.query('''
SELECT DISTINCT bike_type
FROM ftds-hacktiv8-project.practice.bike_rent
''').to_dataframe()

df_bike_type_unique2
# Out:
#   bike_type
# 0   classic
# 1  electric

# %% [markdown]
# #####3. Berapa banyak total peminjaman sepeda pada tahun 2016 dan 2017?

# %%
# working area
df_rent_2016_2017 = client.query('''
SELECT
  EXTRACT(YEAR FROM start_time) AS year_time,
  COUNT(*) as total_trip
FROM ftds-hacktiv8-project.practice.bike_rent
WHERE EXTRACT(YEAR FROM start_time) IN (2016,2017)
GROUP BY year_time
''').to_dataframe()

df_rent_2016_2017
# Out:
#    year_time  total_trip
# 0       2017        4539
# 1       2016        3454

# %% [markdown]
# #####4. Dimana station yang paling banyak dikunjungi sebagai titik keberangkatan pada tahun 2016?

# %%
# working area
df_often = client.query('''
SELECT
  start_station_name,
  COUNT(*) as total
FROM ftds-hacktiv8-project.practice.bike_rent
WHERE EXTRACT(YEAR FROM start_time) = 2016
GROUP BY start_station_name
ORDER BY total DESC
LIMIT 1
''').to_dataframe()

df_often
# Out:
#                 start_station_name  total
# 0  Bullock Museum @ Congress & MLK    394

# %% [markdown]
# #####5. Berapa nilai minimum, maximum, dan rata-rata dari durasi perjalanan pada keseluruhan data?

# %%
# working area
df_5 = client.query('''
SELECT
  MAX(duration_minutes) as Max,
  MIN(duration_minutes) as Min,
  AVG(duration_minutes) as Average
FROM ftds-hacktiv8-project.practice.bike_rent
''').to_dataframe()

df_5
# Out:
#     Max  Min  Average
# 0  2218    2  35.0995

# %% [markdown]
# #####6. Berapa rata-rata durasi perjalanan dari subscriber_type `Student Membership` dan `Local31`?

# %%
# working area
df_6 = client.query('''
SELECT
  subscriber_type,
  MAX(duration_minutes) as Max,
  MIN(duration_minutes) as Min,
  AVG(duration_minutes) as Average
FROM ftds-hacktiv8-project.practice.bike_rent
WHERE subscriber_type IN("U.T. Student Membership", "Local30")
GROUP BY subscriber_type
''').to_dataframe()

df_6
# Out:
#            subscriber_type  Max  Min    Average
# 0                  Local30  497    2  16.021672
# 1  U.T. Student Membership   39   39  39.000000

# %%
df_1['subscriber_type'].value_counts()
# Out:
# subscriber_type
# Walk Up                    4526
# Local365                   1822
# Weekender                   795
# Local30                     646
# Explorer                    210
# U.T. Student Membership       1
# Name: count, dtype: int64

# %% [markdown]
# #####7. Tampilkan entry data yang memiliki `duration_time` diatas 4.25 jam. (*Gunakan subquery untuk menjawab pertanyaan ini dengan meng-convert duration_time dari menit ke hour*).

# %%
# working area

df_7 = client.query('''
SELECT *
FROM (
  SELECT *,
  (duration_minutes/60 ) AS duration_time
FROM ftds-hacktiv8-project.practice.bike_rent)
WHERE duration_time > 4.25
''').to_dataframe()

df_7
# Out:
#      trip_id subscriber_type bike_id bike_type                start_time  \
# 0   13255686         Walk Up     539   classic 2016-12-25 11:17:16+00:00
# 1   13255691         Walk Up     453   classic 2016-12-25 11:18:17+00:00
# 2   14534164         Walk Up     664   classic 2017-04-21 20:46:17+00:00
# 3   14534142         Walk Up     275   classic 2017-04-21 20:41:54+00:00
# 4   11965934         Walk Up     453   classic 2016-09-17 11:55:23+00:00
# ..       ...             ...     ...       ...                       ...
# 86  14699898         Walk Up     262   classic 2017-05-06 09:08:08+00:00
# 87   9516320         Walk Up     157   classic 2016-04-11 13:19:09+00:00
# 88  14465838         Walk Up     871   classic 2017-04-16 12:39:51+00:00
# 89  15884138         Walk Up     882   classic 2017-09-07 19:11:26+00:00
# 90  14087008         Walk Up     221   classic 2017-03-18 00:14:37+00:00
#
#                          start_station_name  \
# 0                                Pease Park
# 1                                Pease Park
# 2                    Davis at Rainey Street
# 3                    Davis at Rainey Street
# 4           Bullock Museum @ Congress & MLK
# ..                                      ...
# 86          State Capitol @ 14th & Colorado
# 87                             Lavaca & 6th
# 88                 South Congress & Academy
# 89  Capital Metro HQ - East 5th at Broadway
# 90              East 6th at Robert Martinez
#
#                            end_station_name  duration_minutes  duration_time
# 0                                Pease Park               351       5.850000
# 1                                Pease Park               350       5.833333
# 2                                Pease Park               783      13.050000
# 3                                Pease Park               789      13.150000
# 4                              Lavaca & 6th               325       5.416667
# ..                                      ...               ...            ...
# 86          State Capitol @ 14th & Colorado               350       5.833333
# 87          State Capitol @ 14th & Colorado               643      10.716667
# 88          State Capitol @ 14th & Colorado               684      11.400000
# 89  Capital Metro HQ - East 5th at Broadway               292       4.866667
# 90  Capital Metro HQ - East 5th at Broadway               757      12.616667
#
# [91 rows x 9 columns]

# %% [markdown]
# ------------------SOAL LATIHAN TAMBAHAN----------------------
#
#
# Hitung jumlah peminjaman per tipe sepeda per tahun 2017, urut dari yang terbanyak.
#
# Tampilkan 3 subscriber_type dengan durasi perjalanan rata-rata tertinggi pada bulan Juni 2018.
#
# Cari station yang paling sering menjadi tujuan (end_station) untuk member tipe “Explorer” pada kuartal 2 tahun 2019.
#
# Hitung total durasi perjalanan (menit), rata-rata, dan standar deviasi per bike_type untuk tahun 2020.
#
# Tampilkan semua entry dengan durasi > 3 jam, gunakan subquery untuk mengubah durasi dari menit ke jam.
#
# Hitung berapa banyak perjalanan yang dilakukan setiap member_type, lalu hitung persentase dari total keseluruhan (gunakan subquery).
#
# Tampilkan 5 perjalanan terpanjang per station keberangkatan (start_station) menggunakan GROUP BY dan HAVING.

# %% [markdown]
# 8. Hitung jumlah peminjaman per tipe sepeda per tahun 2017, urut dari yang terbanyak.

# %%
df_8 = client.query('''
SELECT
      bike_type,
      COUNT(*) AS trip_2017
FROM ftds-hacktiv8-project.practice.bike_rent
WHERE EXTRACT(YEAR FROM start_time) = 2017
GROUP BY bike_type
ORDER BY trip_2017 DESC
''').to_dataframe()

df_8
# Out:
#   bike_type  trip_2017
# 0   classic       4530
# 1  electric          9

# %% [markdown]
# 9. Tampilkan 3 subscriber_type dengan durasi perjalanan rata-rata tertinggi pada bulan Juni 2018.

# %%
df_9 = client.query('''
SELECT
      subscriber_type,
      AVG(duration_minutes) AS avg_sub
FROM ftds-hacktiv8-project.practice.bike_rent
WHERE EXTRACT(YEAR FROM start_time) = 2017 AND EXTRACT(MONTH FROM start_time) = 6
GROUP BY subscriber_type
ORDER BY avg_sub DESC
LIMIT 3
''').to_dataframe()

df_9
# Out:
#   subscriber_type    avg_sub
# 0        Explorer  61.111111
# 1       Weekender  57.903226
# 2         Walk Up  55.601504

# %% [markdown]
# 10. Cari station yang paling sering menjadi tujuan (end_station) untuk member tipe “Explorer” pada kuartal 2 tahun 2019.

# %%
df_10 = client.query('''
SELECT
      end_station_name,
      COUNT(*) AS more_end
FROM ftds-hacktiv8-project.practice.bike_rent
WHERE subscriber_type = 'Explorer'
  AND EXTRACT(YEAR FROM start_time) = 2019
  AND EXTRACT(QUARTER FROM start_time) = 2
GROUP BY end_station_name
ORDER BY more_end DESC

''').to_dataframe()

df_10
# Out:
# Empty DataFrame
# Columns: [end_station_name, more_end]
# Index: []

# %% [markdown]
# 11. Hitung total durasi perjalanan (menit), rata-rata, dan standar deviasi per bike_type untuk tahun 2020.

# %%
df_11 = client.query('''
SELECT
      bike_type,
      SUM(duration_minutes) AS sum,
      AVG(duration_minutes) AS avg,
      STDDEV(duration_minutes) AS std
FROM ftds-hacktiv8-project.practice.bike_rent
WHERE EXTRACT(YEAR FROM start_time) =2020
GROUP BY bike_type

''').to_dataframe()

df_11
# Out:
# Empty DataFrame
# Columns: [bike_type, sum, avg, std]
# Index: []

# %% [markdown]
# 12. Tampilkan semua entry dengan durasi > 3 jam, gunakan subquery untuk mengubah durasi dari menit ke jam.

# %%
df_12 = client.query('''
SELECT
      *
FROM (
      SELECT
            *,
            duration_minutes /60 AS duration_hours
      FROM ftds-hacktiv8-project.practice.bike_rent)
WHERE duration_hours >3
ORDER BY duration_hours
''').to_dataframe()

df_12
# Out:
#       trip_id subscriber_type bike_id bike_type                start_time  \
# 0    15662009         Walk Up     410   classic 2017-08-13 16:32:04+00:00
# 1    15662011         Walk Up     507   classic 2017-08-13 16:32:57+00:00
# 2    13655160         Walk Up     666   classic 2017-02-07 10:57:57+00:00
# 3    14766785         Local30     881   classic 2017-05-11 21:01:13+00:00
# 4    14699908         Walk Up     621   classic 2017-05-06 09:09:07+00:00
# ..        ...             ...     ...       ...                       ...
# 148  10197780         Walk Up     354   classic 2016-05-28 03:34:42+00:00
# 149  10047507       Weekender      97   classic 2016-05-18 15:12:37+00:00
# 150  15912175         Walk Up     663   classic 2017-09-10 16:08:17+00:00
# 151  10087505         Walk Up     895   classic 2016-05-21 01:20:46+00:00
# 152  14871392         Walk Up     141   classic 2017-05-21 02:53:02+00:00
#
#                   start_station_name                 end_station_name  \
# 0                    Henderson & 9th                  Henderson & 9th
# 1                    Henderson & 9th                  Henderson & 9th
# 2                    Guadalupe & 6th                  Guadalupe & 6th
# 3                  Palmer Auditorium       Barton Springs & Riverside
# 4    State Capitol @ 14th & Colorado  State Capitol @ 14th & Colorado
# ..                               ...                              ...
# 148                     Lavaca & 6th                     Lavaca & 6th
# 149       East 7th & Pleasant Valley                     Lavaca & 6th
# 150                  Henderson & 9th                  Henderson & 9th
# 151   East 11th St. at Victory Grill   East 11th St. at Victory Grill
# 152                     Lavaca & 6th               13th & San Antonio
#
#      duration_minutes  duration_hours
# 0                 181        3.016667
# 1                 181        3.016667
# 2                 182        3.033333
# 3                 182        3.033333
# 4                 182        3.033333
# ..                ...             ...
# 148              1064       17.733333
# 149              1126       18.766667
# 150              1160       19.333333
# 151              2113       35.216667
# 152              2218       36.966667
#
# [153 rows x 9 columns]

# %% [markdown]
# versi pandas
# Tambah kolom duration_hours.
# df['duration_hours'] = df['duration_minutes'] / 60
#
# Filter durasi lebih dari 3 jam
# df_long = df[df['duration_hours'] > 3]
#
# Urutkan berdasarkan durasi_hours
# df_long = df_long.sort_values('duration_hours')
#
# Tampilkan
# df_long

# %% [markdown]
# 13. Hitung berapa banyak perjalanan yang dilakukan setiap member_type, lalu hitung persentase dari total keseluruhan (gunakan subquery).

# %%
df_13 = client.query('''

SELECT
      subscriber_type,
      COUNT(*) /
      ( SELECT
              COUNT(*)
        FROM ftds-hacktiv8-project.practice.bike_rent ) * 100
        as persentase
FROM ftds-hacktiv8-project.practice.bike_rent
GROUP BY subscriber_type
''').to_dataframe()

df_13
# Out:
#            subscriber_type  persentase
# 0                 Explorer      2.6250
# 1                 Local365     22.7750
# 2                  Walk Up     56.5750
# 3                Weekender      9.9375
# 4                  Local30      8.0750
# 5  U.T. Student Membership      0.0125

# %% [markdown]
# 14. Tampilkan 5 perjalanan terpanjang per station keberangkatan (start_station) menggunakan GROUP BY dan HAVING.

# %%
df_14 = client.query('''

SELECT
    start_station_name,
    MAX(duration_minutes) AS max_trip
FROM ftds-hacktiv8-project.practice.bike_rent
GROUP BY start_station_name
HAVING MAX(duration_minutes) IS NOT NULL
ORDER BY max_trip DESC
LIMIT 5;

''').to_dataframe()

df_14
# Out:
#                start_station_name  max_trip
# 0                    Lavaca & 6th      2218
# 1  East 11th St. at Victory Grill      2113
# 2                 Henderson & 9th      1160
# 3      East 7th & Pleasant Valley      1126
# 4          Davis at Rainey Street       955

# %% [markdown]
# ###**Pandas**

# %% [markdown]
# #####Data Loading

# %%
# working area
df = client.query('''
SELECT *
FROM ftds-hacktiv8-project.practice.bike_rent
''').to_dataframe()

# %% [markdown]
# #####1. Cek kesesuaian tipe data dan keberadaan missing values dengan `.info()`

# %%
# working area
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 8000 entries, 0 to 7999
# Data columns (total 8 columns):
#  #   Column              Non-Null Count  Dtype
# ---  ------              --------------  -----
#  0   trip_id             8000 non-null   Int64
#  1   subscriber_type     8000 non-null   object
#  2   bike_id             8000 non-null   object
#  3   bike_type           8000 non-null   object
#  4   start_time          8000 non-null   datetime64[us, UTC]
#  5   start_station_name  8000 non-null   object
#  6   end_station_name    8000 non-null   object
#  7   duration_minutes    8000 non-null   Int64
# dtypes: Int64(2), datetime64[us, UTC](1), object(5)
# memory usage: 515.8+ KB

# %% [markdown]
# #####2. Buat kolom baru bernama `quarter`.
#
#   Lakukan ekstraksi waktu (quarter dalam tahun) berdasarkan kolom `start_time` dengan ketentuan berikut:
#
# <div align="center">
#
#   |Keterangan Waktu|Bulan|
#   |--|--|
#   |Q1|Januari, Februari, Maret|
#   |Q2|April, Mei, Juni|
#   |Q3|Juli, Agustus, September|
#   |Q4|Oktober, November, Desember|
#
# </div>
#
# >**Notes:**
# >- Dalam menjawab soal Pandas no. 2, **tidak boleh** menggunakan ekstraksi waktu `Series.dt.quarter`.
# - Lakukan `looping` dan `conditional` dengan memanfaatkan ekstraksi bulan `Series.dt.month` terhadap kolom `start_time`, pastikan tipe datanya ialah `datetime` agar dapat dilakukan ekstraksi.
# - Simpan hasil looping ke dalam suatu variabel, dan buat kolom baru berisikan variabel sebelumnya.

# %%
# working area
import pandas as pd

quarters = []

for month in df['start_time'].dt.month:
  if month in [1,2,3]:
    quarters.append('Q1')
  elif month in [4,5,6]:
    quarters.append('Q2')
  elif month in [7,8,9]:
    quarters.append('Q3')
  else:
    quarters.append('Q4')

df['quarter'] = quarters

df[['start_time', 'quarter']]
# Out:
#                     start_time quarter
# 0    2018-10-28 14:16:14+00:00      Q4
# 1    2017-03-07 12:37:33+00:00      Q1
# 2    2017-10-21 09:49:48+00:00      Q4
# 3    2017-10-18 15:01:52+00:00      Q4
# 4    2017-10-18 15:02:26+00:00      Q4
# ...                        ...     ...
# 7995 2017-07-22 20:17:46+00:00      Q3
# 7996 2017-10-07 11:25:36+00:00      Q4
# 7997 2017-03-27 13:19:02+00:00      Q1
# 7998 2017-06-05 11:42:40+00:00      Q2
# 7999 2016-04-09 18:52:09+00:00      Q2
#
# [8000 rows x 2 columns]

# %% [markdown]
# #####3. Tampilkan data perjalanan dari tipe member `Local31` dengan durasi perjalanan diatas 1 jam.
# *(Jika tidak ada entry yang memenuhi kondisi ini tidak apa, tuliskan kode pandasnya dengan lengkap saja)*

# %%
# working area

df_3b = df[
            (df['subscriber_type'] == "Local31") &
            (df['duration_minutes'] > 60)
][['subscriber_type', 'duration_minutes']]

df_3b
# Out:
# Empty DataFrame
# Columns: [subscriber_type, duration_minutes]
# Index: []

# %% [markdown]
# #####4. Berapa rata-rata durasi perjalanan dari tipe pelanggan `Walk Up` dengan tipe sepeda `classic` pada bulan `Maret` dari data yang diambil?
# *(Jika tidak ada entry yang memenuhi kondisi ini tidak apa, tuliskan kode pandasnya dengan lengkap saja)*

# %%
# working area

df_4b = df[
            (df['subscriber_type'] == "Walk Up") &
            (df['bike_type'] == "classic") &
            (df['start_time'].dt.month == 3 )
][['subscriber_type', 'bike_type', 'start_time', 'duration_minutes']]

df_avg = df_4b['duration_minutes'].mean()

df_avg
# Out:
# np.float64(38.476584022038566)

# %% [markdown]
# 5. Tampilkan semua perjalanan dari tipe member "Local365" dengan durasi > 60 menit. Tampilkan kolom subscriber_type dan duration_minutes.

# %%
df_5b = df[
            (df['subscriber_type'] == "Local365") &
            (df['duration_minutes'] > 60)
][['subscriber_type', 'duration_minutes']]

df_5b
# Out:
#      subscriber_type  duration_minutes
# 1           Local365               198
# 94          Local365                81
# 165         Local365               147
# 359         Local365               134
# 401         Local365               823
# 428         Local365               123
# 453         Local365                77
# 608         Local365               290
# 609         Local365               269
# 704         Local365               113
# 724         Local365                95
# 728         Local365               162
# 754         Local365                76
# 893         Local365               146
# 896         Local365               164
# 956         Local365               609
# 1101        Local365               192
# 1155        Local365                62
# 1179        Local365                93

# %%
df_5b = df.loc[
    (df['subscriber_type'] == "Local365") &
    (df['duration_minutes'] > 60),
    ['subscriber_type', 'duration_minutes']
]
df_5b
# Out:
#      subscriber_type  duration_minutes
# 1           Local365               198
# 94          Local365                81
# 165         Local365               147
# 359         Local365               134
# 401         Local365               823
# 428         Local365               123
# 453         Local365                77
# 608         Local365               290
# 609         Local365               269
# 704         Local365               113
# 724         Local365                95
# 728         Local365               162
# 754         Local365                76
# 893         Local365               146
# 896         Local365               164
# 956         Local365               609
# 1101        Local365               192
# 1155        Local365                62
# 1179        Local365                93

# %%
df_5b = df.query('subscriber_type == "Local365" & duration_minutes > 60')[
    ['subscriber_type', 'duration_minutes']
]
df_5b
# Out:
# /tmp/ipython-input-3585011205.py:1: RuntimeWarning: Engine has switched to 'python' because numexpr does not support extension array dtypes. Please set your engine to python manually.
#   df_5b = df.query('subscriber_type == "Local365" & duration_minutes > 60')[
#      subscriber_type  duration_minutes
# 1           Local365               198
# 94          Local365                81
# 165         Local365               147
# 359         Local365               134
# 401         Local365               823
# 428         Local365               123
# 453         Local365                77
# 608         Local365               290
# 609         Local365               269
# 704         Local365               113
# 724         Local365                95
# 728         Local365               162
# 754         Local365                76
# 893         Local365               146
# 896         Local365               164
# 956         Local365               609
# 1101        Local365               192
# 1155        Local365                62
# 1179        Local365                93

# %% [markdown]
# 6. Buat kolom baru duration_category:
#
# "Short" < 30 menit
#
# "Medium" 30–60 menit
#
# "Long" > 60 menit

# %%
def duration_ctg(jarak):
  if jarak < 30:
    return "Short"
  elif jarak <=60:
    return "Medium"
  else :
    return "Long"

df['duration_category'] = df['duration_minutes'].apply(duration_ctg)

df[['duration_minutes', 'duration_category']]
# Out:
#       duration_minutes duration_category
# 0                  178              Long
# 1                  198              Long
# 2                   60            Medium
# 3                   60            Medium
# 4                   60            Medium
# ...                ...               ...
# 7995                55            Medium
# 7996                55            Medium
# 7997                55            Medium
# 7998                55            Medium
# 7999                55            Medium
#
# [8000 rows x 2 columns]

# %% [markdown]
# 7. Pandas Query
#
# Soal: Tampilkan perjalanan "Walk Up" dengan sepeda "classic" di bulan Maret.

# %%
df_7b = df.query('subscriber_type == "Walk Up" & bike_type == "classic" & start_time.dt.month == 3')[['subscriber_type', 'bike_type', 'start_time']]

df_7b
# Out:
#      subscriber_type bike_type                start_time
# 22           Walk Up   classic 2017-03-10 14:07:44+00:00
# 23           Walk Up   classic 2017-03-10 14:07:30+00:00
# 25           Walk Up   classic 2017-03-07 18:19:10+00:00
# 26           Walk Up   classic 2017-03-07 18:21:51+00:00
# 27           Walk Up   classic 2017-03-07 18:20:50+00:00
# ...              ...       ...                       ...
# 7918         Walk Up   classic 2017-03-25 17:41:18+00:00
# 7958         Walk Up   classic 2017-03-10 14:08:06+00:00
# 7969         Walk Up   classic 2017-03-27 18:23:19+00:00
# 7992         Walk Up   classic 2017-03-06 16:28:01+00:00
# 7997         Walk Up   classic 2017-03-27 13:19:02+00:00
#
# [363 rows x 3 columns]

# %%
df_7b = df.query('subscriber_type == "Walk Up" & bike_type == "classic" & start_time.dt.month == 3')

df_7b
# Out:
#        trip_id subscriber_type bike_id bike_type                start_time  \
# 22    13988611         Walk Up     578   classic 2017-03-10 14:07:44+00:00
# 23    13988602         Walk Up      72   classic 2017-03-10 14:07:30+00:00
# 25    13953899         Walk Up     398   classic 2017-03-07 18:19:10+00:00
# 26    13953935         Walk Up      14   classic 2017-03-07 18:21:51+00:00
# 27    13953917         Walk Up     127   classic 2017-03-07 18:20:50+00:00
# ...        ...             ...     ...       ...                       ...
# 7918  14186820         Walk Up     349   classic 2017-03-25 17:41:18+00:00
# 7958  13988616         Walk Up     522   classic 2017-03-10 14:08:06+00:00
# 7969  14210328         Walk Up     352   classic 2017-03-27 18:23:19+00:00
# 7992  13940556         Walk Up     106   classic 2017-03-06 16:28:01+00:00
# 7997  14204138         Walk Up     235   classic 2017-03-27 13:19:02+00:00
#
#                    start_station_name                 end_station_name  \
# 22    Bullock Museum @ Congress & MLK                       Pease Park
# 23    Bullock Museum @ Congress & MLK                       Pease Park
# 25                         Pease Park                       Pease Park
# 26                         Pease Park                       Pease Park
# 27                         Pease Park                       Pease Park
# ...                               ...                              ...
# 7918                       Pease Park                       Pease Park
# 7958  Bullock Museum @ Congress & MLK                       Pease Park
# 7969               11th & San Jacinto               11th & San Jacinto
# 7992         South Congress & Academy   East 11th St. at Victory Grill
# 7997  State Capitol @ 14th & Colorado  State Capitol @ 14th & Colorado
#
#       duration_minutes duration_category  month month_name
# 22                  56            Medium      3      March
# 23                  56            Medium      3      March
# 25                 107              Long      3      March
# 26                 105              Long      3      March
# 27                 106              Long      3      March
# ...                ...               ...    ...        ...
# 7918                54            Medium      3      March
# 7958                55            Medium      3      March
# 7969                55            Medium      3      March
# 7992                55            Medium      3      March
# 7997                55            Medium      3      March
#
# [363 rows x 11 columns]

# %% [markdown]
# 8. Pemrosesan Datetime
# Extract bulan & nama bulan:
#
# df['month'] = df['start_time'].dt.month
# df['month_name'] = df['start_time'].dt.month_name()

# %%
df['month'] = df['start_time'].dt.month
df['month_name'] = df['start_time'].dt.month_name()

df
# Out:
#        trip_id subscriber_type bike_id bike_type                start_time  \
# 0     18896589        Explorer      93   classic 2018-10-28 14:16:14+00:00
# 1     13948351        Local365     315   classic 2017-03-07 12:37:33+00:00
# 2     16243803        Local365     877   classic 2017-10-21 09:49:48+00:00
# 3     16222446         Walk Up     273   classic 2017-10-18 15:01:52+00:00
# 4     16222451         Walk Up     201   classic 2017-10-18 15:02:26+00:00
# ...        ...             ...     ...       ...                       ...
# 7995  15469480         Walk Up     327   classic 2017-07-22 20:17:46+00:00
# 7996  16130650         Walk Up     528   classic 2017-10-07 11:25:36+00:00
# 7997  14204138         Walk Up     235   classic 2017-03-27 13:19:02+00:00
# 7998  15037809         Walk Up     206   classic 2017-06-05 11:42:40+00:00
# 7999   9499076         Walk Up     315   classic 2016-04-09 18:52:09+00:00
#
#                            start_station_name  \
# 0                     Dean Keeton & Speedway
# 1                                 Main Office
# 2           Republic Square @ 5th & Guadalupe
# 3             Bullock Museum @ Congress & MLK
# 4             Bullock Museum @ Congress & MLK
# ...                                       ...
# 7995          Bullock Museum @ Congress & MLK
# 7996                  Congress & Cesar Chavez
# 7997          State Capitol @ 14th & Colorado
# 7998          State Capitol @ 14th & Colorado
# 7999  Capital Metro HQ - East 5th at Broadway
#
#                              end_station_name  duration_minutes  \
# 0                              11th & Salina                178
# 1                                 Main Office               198
# 2                                 Main Office                60
# 3                                 Main Office                60
# 4                                 Main Office                60
# ...                                       ...               ...
# 7995          Bullock Museum @ Congress & MLK                55
# 7996          Bullock Museum @ Congress & MLK                55
# 7997          State Capitol @ 14th & Colorado                55
# 7998          State Capitol @ 14th & Colorado                55
# 7999  Capital Metro HQ - East 5th at Broadway                55
#
#      duration_category  month month_name
# 0                 Long     10    October
# 1                 Long      3      March
# 2               Medium     10    October
# 3               Medium     10    October
# 4               Medium     10    October
# ...                ...    ...        ...
# 7995            Medium      7       July
# 7996            Medium     10    October
# 7997            Medium      3      March
# 7998            Medium      6       June
# 7999            Medium      4      April
#
# [8000 rows x 11 columns]

# %% [markdown]
# 9. Hitung durasi perjalanan dari start & end time:
# df['trip_diff_minutes'] = (df['end_time'] - df['start_time']).dt.total_seconds() / 60

# %% [markdown]
# 10. Tambah waktu (date_add):
# df['expected_return'] = df['start_time'] + pd.Timedelta(hours=1)

# %%
import pandas as pd

df['expected_return'] = df['start_time'] + pd.Timedelta(hours=1)

df
# Out:
#        trip_id subscriber_type bike_id bike_type                start_time  \
# 0     18896589        Explorer      93   classic 2018-10-28 14:16:14+00:00
# 1     13948351        Local365     315   classic 2017-03-07 12:37:33+00:00
# 2     16243803        Local365     877   classic 2017-10-21 09:49:48+00:00
# 3     16222446         Walk Up     273   classic 2017-10-18 15:01:52+00:00
# 4     16222451         Walk Up     201   classic 2017-10-18 15:02:26+00:00
# ...        ...             ...     ...       ...                       ...
# 7995  15469480         Walk Up     327   classic 2017-07-22 20:17:46+00:00
# 7996  16130650         Walk Up     528   classic 2017-10-07 11:25:36+00:00
# 7997  14204138         Walk Up     235   classic 2017-03-27 13:19:02+00:00
# 7998  15037809         Walk Up     206   classic 2017-06-05 11:42:40+00:00
# 7999   9499076         Walk Up     315   classic 2016-04-09 18:52:09+00:00
#
#                            start_station_name  \
# 0                     Dean Keeton & Speedway
# 1                                 Main Office
# 2           Republic Square @ 5th & Guadalupe
# 3             Bullock Museum @ Congress & MLK
# 4             Bullock Museum @ Congress & MLK
# ...                                       ...
# 7995          Bullock Museum @ Congress & MLK
# 7996                  Congress & Cesar Chavez
# 7997          State Capitol @ 14th & Colorado
# 7998          State Capitol @ 14th & Colorado
# 7999  Capital Metro HQ - East 5th at Broadway
#
#                              end_station_name  duration_minutes  \
# 0                              11th & Salina                178
# 1                                 Main Office               198
# 2                                 Main Office                60
# 3                                 Main Office                60
# 4                                 Main Office                60
# ...                                       ...               ...
# 7995          Bullock Museum @ Congress & MLK                55
# 7996          Bullock Museum @ Congress & MLK                55
# 7997          State Capitol @ 14th & Colorado                55
# 7998          State Capitol @ 14th & Colorado                55
# 7999  Capital Metro HQ - East 5th at Broadway                55
#
#      duration_category  month month_name           expected_return
# 0                 Long     10    October 2018-10-28 15:16:14+00:00
# 1                 Long      3      March 2017-03-07 13:37:33+00:00
# 2               Medium     10    October 2017-10-21 10:49:48+00:00
# 3               Medium     10    October 2017-10-18 16:01:52+00:00
# 4               Medium     10    October 2017-10-18 16:02:26+00:00
# ...                ...    ...        ...                       ...
# 7995            Medium      7       July 2017-07-22 21:17:46+00:00
# 7996            Medium     10    October 2017-10-07 12:25:36+00:00
# 7997            Medium      3      March 2017-03-27 14:19:02+00:00
# 7998            Medium      6       June 2017-06-05 12:42:40+00:00
# 7999            Medium      4      April 2016-04-09 19:52:09+00:00
#
# [8000 rows x 12 columns]
